# %%
MyDictionary = {'key1':'value1', 'key2':'value2'}

# %%
StudentDetails = {"FirstName":"Eric", "LastName":"Kisu", "Age":24, "Location":"Machakos"}
print(StudentDetails)
print(StudentDetails.keys())
# Out:
# {'FirstName': 'Eric', 'LastName': 'Kisu', 'Age': 24, 'Location': 'Machakos'}
# dict_keys(['FirstName', 'LastName', 'Age', 'Location'])

# %%
StudentDetails.values()
# Out:
# dict_values(['Eric', 'Kisu', 24, 'Machakos'])

# %%
StudentDetails.items()
# Out:
# dict_items([('FirstName', 'Eric'), ('LastName', 'Kisu'), ('Age', 24), ('Location', 'Machakos')])

# %% [markdown]
# ## Adding items

# %%
StudentDetails["Height"] = 3.5

# %%
StudentDetails
# Out:
# {'FirstName': 'Eric',
#  'LastName': 'Kisu',
#  'Age': 24,
#  'Location': 'Machakos',
#  'Height': 3.5}

# %%
StudentDetails.update({"Height": 5.4})

# %%
StudentDetails
# Out:
# {'FirstName': 'Eric',
#  'LastName': 'Kisu',
#  'Age': 24,
#  'Location': 'Machakos',
#  'Height': 5.4}

# %% [markdown]
# ## Copying

# %%
# same as lists
StudentDetailsCopy = StudentDetails.copy()

# %%
StudentDetailsCopy2 = StudentDetails
StudentDetailsCopy
StudentDetailsCopy2
# Out:
# {'FirstName': 'Eric',
#  'LastName': 'Kisu',
#  'Age': 24,
#  'Location': 'Machakos',
#  'Height': 5.4}

# %% [markdown]
# ## Deleting

# %%
# same as list
StudentDetails.pop("FirstName")
# Out:
# 'Eric'

# %%
StudentDetails
# Out:
# {'LastName': 'Kisu', 'Age': 24, 'Location': 'Machakos', 'Height': 5.4}

# %%
StudentDetails["FirstName"] =  "Deric"

# %%
StudentDetails
# Out:
# {'LastName': 'Kisu',
#  'Age': 24,
#  'Location': 'Machakos',
#  'Height': 5.4,
#  'FirstName': 'Deric'}

# %%
del StudentDetails["FirstName"]

# %%
StudentDetails
# Out:
# {'LastName': 'Kisu', 'Age': 24, 'Location': 'Machakos', 'Height': 5.4}

# %%
StudentDetails.clear()

# %%
StudentDetails
# Out:
# {}
