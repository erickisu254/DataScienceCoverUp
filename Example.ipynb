# %% [markdown]
# # Python

# %%
Countries = [ "USA", "Turkey", "Kenya"]
for CurrentCountry in Countries:
    print(CurrentCountry)
# Out:
# USA
# Turkey
# Kenya

# %%
Students = ["Eric", "Kisu", "Nzuma", "Evans", "Mule", "Nzuma", "Eva", "Mueni", "Nzuma"]
for CurrentStudent in Students:
    print (CurrentStudent)
print(Students[-3])
# Out:
# Eric
# Kisu
# Nzuma
# Evans
# Mule
# Nzuma
# Eva
# Mueni
# Nzuma
# Eva
