# %% [markdown]
# ## If Statements

# %%
StudentGrades = [32, 54, 21, 23, 67, 98, 43, 56, 20, 46, 67, 21, 67, 25, 50]
for i, IndividualGrades in enumerate(StudentGrades):
    if IndividualGrades > 50 :
        # print(i)
        print("you passed")
    elif IndividualGrades >= 25:
        # print(i)
        print("you bearly made it")
    else :
        # print(i)
        print("failed")
print(len(StudentGrades))
# Out:
# you bearly made it
# you passed
# failed
# failed
# you passed
# you passed
# you bearly made it
# you passed
# failed
# you bearly made it
# you passed
# failed
# you passed
# you bearly made it
# you bearly made it
# 15

# %% [markdown]
# ##### for key, value in <dict_name>.items():
# #####      print(key)
# #####      print(value)
