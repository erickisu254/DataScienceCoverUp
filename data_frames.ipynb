# %% [markdown]
# # **Dataframes**

# %%
import pandas as pd
import numpy as np

# %%
# List
data = np.array([["Eric",5], ["Dan",7], ["Eva",9],["Ref",4]])
# with no numpy
# data = [["Eric",5], ["Dan",7], ["Eva",9],["Ref",4]]

# %%
# dataframe with pandas
df =pd.DataFrame(data, index=['Stu1', 'Stu2', 'Stu3', 'Stu4'], columns=['Name', 'Age'])

# %%
df
# Out:
#       Name Age
# Stu1  Eric   5
# Stu2   Dan   7
# Stu3   Eva   9
# Stu4   Ref   4

# %%
# DataFrames From Dicts

States = ["California", "Texas", "Florida", "New York", "Kentucky"]
Population =[23456, 4456, 4567, 4567, 4563]

# %%
dict_states = {"States":States, "Population in Thousands":Population}

# %%
df_population = pd.DataFrame(dict_states)

# %%
df_population
# Out:
#        States  Population in Thousands
# 0  California                    23456
# 1       Texas                     4456
# 2     Florida                     4567
# 3    New York                     4567
# 4    Kentucky                     4563

# %%
df_population = pd.DataFrame(dict_states, index=['State1', 'State2', 'State3', 'State4', 'State5'])

# %%
df_population
# Out:
#             States  Population in Thousands
# State1  California                    23456
# State2       Texas                     4456
# State3     Florida                     4567
# State4    New York                     4567
# State5    Kentucky                     4563

# %%
# from a CSV file
df_csv = pd.read_csv("data.csv" , encoding='latin-1')
# Out:
# /tmp/ipykernel_101149/2329482321.py:2: DtypeWarning: Columns (6,7,28) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_csv = pd.read_csv("data.csv" , encoding='latin-1')

# %%
# Showing the data
df_csv.head(10)
# Out:
#          Event.Id Investigation.Type Accident.Number  Event.Date  \
# 0  20001218X45444           Accident      SEA87LA080  1948-10-24
# 1  20001218X45447           Accident      LAX94LA336  1962-07-19
# 2  20061025X01555           Accident      NYC07LA005  1974-08-30
# 3  20001218X45448           Accident      LAX96LA321  1977-06-19
# 4  20041105X01764           Accident      CHI79FA064  1979-08-02
# 5  20170710X52551           Accident      NYC79AA106  1979-09-17
# 6  20001218X45446           Accident      CHI81LA106  1981-08-01
# 7  20020909X01562           Accident      SEA82DA022  1982-01-01
# 8  20020909X01561           Accident      NYC82DA015  1982-01-01
# 9  20020909X01560           Accident      MIA82DA029  1982-01-01
#
#            Location        Country   Latitude  Longitude Airport.Code  \
# 0   MOOSE CREEK, ID  United States        NaN        NaN          NaN
# 1    BRIDGEPORT, CA  United States        NaN        NaN          NaN
# ...

# %%
df_csv.tail()
# Out:
#              Event.Id Investigation.Type Accident.Number  Event.Date  \
# 88884  20221227106491           Accident      ERA23LA093  2022-12-26
# 88885  20221227106494           Accident      ERA23LA095  2022-12-26
# 88886  20221227106497           Accident      WPR23LA075  2022-12-26
# 88887  20221227106498           Accident      WPR23LA076  2022-12-26
# 88888  20221230106513           Accident      ERA23LA097  2022-12-29
#
#             Location        Country Latitude Longitude Airport.Code  \
# 88884  Annapolis, MD  United States      NaN       NaN          NaN
# 88885    Hampton, NH  United States      NaN       NaN          NaN
# 88886     Payson, AZ  United States  341525N  1112021W          PAN
# 88887     Morgan, UT  United States      NaN       NaN          NaN
# 88888     Athens, GA  United States      NaN       NaN          NaN
#
#       Airport.Name  ... Purpose.of.flight         Air.carrier  \
# 88884          NaN  ...          Personal                 NaN
# ...

# %%
# shape of the data
df_csv.shape
# Out:
# (88889, 31)
